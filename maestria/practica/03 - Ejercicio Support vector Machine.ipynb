# %% [markdown]
# <a href="https://colab.research.google.com/github/dieguito1331/cienciaDatos/blob/master/maestria/practica/03 - Ejercicio Support vector Machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio ##
# 1) Levantar la base finalOrders.txt creada en el primer ejercicio.
# 2) Realizar una división de la base de un 80% para entrenar y un 20% para validar el modelo. ¿Cuántos registros tenemos para entrenar? ¿Y para validar? Usar el parámetro necesario para poder realizar siempre las mismas divisiones
# 3) ¿Debo cambiar el target para ejecutar el modelo?. Te recomiendo contestar esta pregunta luego de ejecutar algún modelo.
# 4) Entrenar un _Support Vector_ utilizando el kernel lineal. Utilizando todos los hiperparámetros por defecto.
# 5) ¿Cuál es el accuracy del modelo? Es adecuada la medida para medir la efectividad del modelo. Si el target hubiera estado desbalanceado, por ejemplo un 98% no devoluciones y 2% devoluciones, qué métrica sería la ideal para medir la performance del modelo?
# 6) Graficar la curva ROC del modelo creado en el punto 4)
# 7) Cear un 2 modelo modificando algún hiperparámetro que nos garantice una mejora en el AUC. ¿Qué hiperparámetro elegiste? Cuál fue la mejora obtenida?
