# %% [markdown]
# ## Utilizacion de librerías en Python ##
# Para poder utilizar funciones de alguna librería en particular se debe importar la misma utilizando la palabra "import"
# se puede sólo importar un módulo de la librería utilizando la palabra "from"
#
# Ejemplos:
#
# 1) import random
# 2) from datetime import datetime
#
# Si la librería no se encuentra instalada, se puede instalar con el comando:
# !pip install pandas
#
# Si quiero instalar una versión específica de una libería se debe especificar a la hora de instalarla:
#
# !pip install selenium==4.0.0

# %%
import random
numeros = [x for x in range(0,100)]
print(random.choice(numeros))
# Out:
# 61

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==3.4.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: argon2-cffi==21.1.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 2)) (21.1.0)
# Requirement already satisfied: async-generator==1.10 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 3)) (1.10)
# Requirement already satisfied: attrs==21.2.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 4)) (21.2.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Babel==2.9.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 5)) (2.9.1)
# Requirement already satisfied: backcall==0.2.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 6)) (0.2.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'D:\Users\900214017\Documents\proyectos\cursoiudu\ambiente\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: beautifulsoup4==4.9.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 7)) (4.9.3)
# Requirement already satisfied: bleach==4.1.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 8)) (4.1.0)
# Requirement already satisfied: certifi==2021.10.8 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 9)) (2021.10.8)
# Requirement already satisfied: cffi==1.15.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 10)) (1.15.0)
# Requirement already satisfied: charset-normalizer==2.0.8 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 11)) (2.0.8)
# Requirement already satisfied: colorama==0.4.4 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 12)) (0.4.4)
# Requirement already satisfied: cryptography==36.0.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 13)) (36.0.0)
# Requirement already satisfied: cycler==0.11.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 14)) (0.11.0)
# Requirement already satisfied: debugpy==1.5.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 15)) (1.5.1)
# Requirement already satisfied: decorator==5.1.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 16)) (5.1.0)
# Requirement already satisfied: defusedxml==0.7.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: entrypoints==0.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 18)) (0.3)
# Requirement already satisfied: fonttools==4.28.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 19)) (4.28.2)
# Requirement already satisfied: h11==0.12.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 20)) (0.12.0)
# Requirement already satisfied: idna==3.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 21)) (3.3)
# Requirement already satisfied: ipykernel==6.5.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 22)) (6.5.1)
# Requirement already satisfied: ipython==7.30.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 23)) (7.30.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 24)) (0.2.0)
# Requirement already satisfied: jedi==0.18.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 25)) (0.18.1)
# Requirement already satisfied: Jinja2==3.0.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 26)) (3.0.3)
# Requirement already satisfied: json5==0.9.6 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 27)) (0.9.6)
# Requirement already satisfied: jsonschema==4.2.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 28)) (4.2.1)
# Requirement already satisfied: jupyter-client==7.1.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 29)) (7.1.0)
# Requirement already satisfied: jupyter-core==4.9.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 30)) (4.9.1)
# Requirement already satisfied: jupyter-server==1.12.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 31)) (1.12.1)
# Requirement already satisfied: jupyterlab==3.2.4 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 32)) (3.2.4)
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 33)) (0.1.2)
# Requirement already satisfied: jupyterlab-server==2.8.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 34)) (2.8.2)
# Requirement already satisfied: kiwisolver==1.3.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 35)) (1.3.2)
# Requirement already satisfied: MarkupSafe==2.0.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 36)) (2.0.1)
# Requirement already satisfied: matplotlib==3.5.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 37)) (3.5.0)
# Requirement already satisfied: matplotlib-inline==0.1.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 38)) (0.1.3)
# Requirement already satisfied: mistune==0.8.4 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 39)) (0.8.4)
# Requirement already satisfied: nbclassic==0.3.4 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 40)) (0.3.4)
# Requirement already satisfied: nbclient==0.5.9 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 41)) (0.5.9)
# Requirement already satisfied: nbconvert==6.3.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 42)) (6.3.0)
# Requirement already satisfied: nbformat==5.1.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 43)) (5.1.3)
# Requirement already satisfied: nest-asyncio==1.5.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 44)) (1.5.1)
# Requirement already satisfied: notebook==6.4.6 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 45)) (6.4.6)
# Requirement already satisfied: numpy==1.21.4 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 46)) (1.21.4)
# Requirement already satisfied: outcome==1.1.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 47)) (1.1.0)
# Requirement already satisfied: packaging==21.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 48)) (21.3)
# Requirement already satisfied: pandas==1.3.4 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 49)) (1.3.4)
# Requirement already satisfied: pandocfilters==1.5.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 50)) (1.5.0)
# Requirement already satisfied: parso==0.8.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 51)) (0.8.2)
# Requirement already satisfied: pickleshare==0.7.5 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 52)) (0.7.5)
# Requirement already satisfied: Pillow==8.4.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 53)) (8.4.0)
# Requirement already satisfied: prometheus-client==0.12.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 54)) (0.12.0)
# Requirement already satisfied: prompt-toolkit==3.0.23 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 55)) (3.0.23)
# Requirement already satisfied: pycparser==2.21 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 56)) (2.21)
# Requirement already satisfied: Pygments==2.10.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 57)) (2.10.0)
# Requirement already satisfied: pyodbc==4.0.32 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 58)) (4.0.32)
# Requirement already satisfied: pyOpenSSL==21.0.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 59)) (21.0.0)
# Requirement already satisfied: pyparsing==3.0.6 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 60)) (3.0.6)
# Requirement already satisfied: pyrsistent==0.18.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 61)) (0.18.0)
# Requirement already satisfied: python-dateutil==2.8.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 62)) (2.8.2)
# Requirement already satisfied: pytz==2021.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 63)) (2021.3)
# Requirement already satisfied: pywin32==302 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 64)) (302)
# Requirement already satisfied: pywinpty==1.1.6 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 65)) (1.1.6)
# Requirement already satisfied: pyzmq==22.3.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 66)) (22.3.0)
# Requirement already satisfied: requests==2.26.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 67)) (2.26.0)
# Requirement already satisfied: scipy==1.7.3 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 68)) (1.7.3)
# Requirement already satisfied: seaborn==0.11.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 69)) (0.11.2)
# Requirement already satisfied: selenium==4.0.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 70)) (4.0.0)
# Requirement already satisfied: Send2Trash==1.8.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 71)) (1.8.0)
# Requirement already satisfied: setuptools-scm==6.3.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 72)) (6.3.2)
# Requirement already satisfied: six==1.16.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 73)) (1.16.0)
# Requirement already satisfied: sniffio==1.2.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 74)) (1.2.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 75)) (2.4.0)
# Requirement already satisfied: soupsieve==2.3.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 76)) (2.3.1)
# Requirement already satisfied: terminado==0.12.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 77)) (0.12.1)
# Requirement already satisfied: testpath==0.5.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 78)) (0.5.0)
# Requirement already satisfied: tomli==1.2.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 79)) (1.2.2)
# Requirement already satisfied: tornado==6.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 80)) (6.1)
# Requirement already satisfied: traitlets==5.1.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 81)) (5.1.1)
# Requirement already satisfied: trio==0.19.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 82)) (0.19.0)
# Requirement already satisfied: trio-websocket==0.9.2 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 83)) (0.9.2)
# Requirement already satisfied: urllib3==1.26.7 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 84)) (1.26.7)
# Requirement already satisfied: wcwidth==0.2.5 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 85)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 86)) (0.5.1)
# Requirement already satisfied: websocket-client==1.2.1 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 87)) (1.2.1)
# Requirement already satisfied: wsproto==1.0.0 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from -r requirements.txt (line 88)) (1.0.0)
# Requirement already satisfied: setuptools>=18.5 in d:\users\900214017\documents\proyectos\cursoiudu\ambiente\lib\site-packages (from ipython==7.30.0->-r requirements.txt (line 23)) (58.1.0)

# %%
from random import seed
from random import random
#Genero una semilla
seed(1)
#Genero los numeros random
print(random(), random(), random())
# Reseteo las semillas
seed(2)
#Genero los numeros random
print(random(), random(), random())

#Utilizo nuevamente la 1era semilla
seed(1)
#Genero los numeros random
print(random(), random(), random())
# Out:
# 0.13436424411240122 0.8474337369372327 0.763774618976614
# 0.9560342718892494 0.9478274870593494 0.05655136772680869
# 0.13436424411240122 0.8474337369372327 0.763774618976614

# %% [markdown]
# # Estructuras de control
#
# ## Comparadores lógicos
#
# | Operador | Acción |
# | -------- | ------ |
# | ==       | igual  |
# | > =       | mayor o igual |
# | >        | mayor estricto |
# | < =      | menor o igual |
# | <     | menor estricto |
# | ! = | desigual|
# | or | o |
# | and | y |

# %%
1 == 1
# Out:
# True

# %%
4 >= 5
# Out:
# False

# %%
#Para validar si un número está en una lista
lista = [1,2,3,4,5,6,7,8,9]
print("el valor 10 esta en la lista? {}".format(10 in lista))
print("el valor 9 esta en la lista? {}".format(9 in lista))
# Out:
# el valor 10 esta en la lista? False
# el valor 9 esta en la lista? True

# %%
print("el valor 10 no esta en la lista? {}".format(10 not in lista))
# Out:
# el valor 10 no esta en la lista? True

# %%
lista_1 = [1,2,3,4,5,6]
lista_2 = lista_1
lista_1.append(7)
print("modifico la lista 1 y me modifica la lista 2 {}".format(lista_2))
# Out:
# modifico la lista 1 y me modifica la lista 2 [1, 2, 3, 4, 5, 6, 7]

# %%
lista_1 = [1,2,3,4,5,6]
lista_2 = lista_1.copy()
lista_1.append(7)
print("modifico la lista 1 y NO me modifica la lista 2 {}".format(lista_2))
# Out:
# modifico la lista 1 y NO me modifica la lista 2 [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Ejercicios Extras ##
#
# 1) Crear una lista con valores del 2 al 50 en intervalos de 2
# 2) Dicha lista convertirla en un diccionario, cuyo key sea cada uno de los valores de la lista y el value el cuadrado del valor
# 3) Agregar al diccionario como key nueva el cuadrado de cada key existente y el value sea al cubo
