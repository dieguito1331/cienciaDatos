# %% [markdown]
# <a href="https://colab.research.google.com/github/dieguito1331/cienciaDatos/blob/master/posgrado/practica/03 - Ejercicio Árboles y Regresión Logística (Orders)-Copy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio ##
# 1) Levantar la base finalOrders.txt creada en el ejercicio anterior.
# 2) Analizar la cantidad de registros y columnas que tiene la base. Utilizar la función shape para dicho punto. [Documentación](https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.shape.html)
# 3) Realizar una división de la base de un 80% para entrenar y un 20% para validar el modelo. ¿Cuántos registros tenemos para entrenar? ¿Y para validar?  Recordar de usar el parámetro random_state para que siempre las particiones sean las mismas. Al parametro usar el valor 30 en random_state.
# 4) Armar un árbol de decisión utilizando los siguientes hiperparámetros:
# *   máxima profundidad = 5
# *   criterio de corte = "entropia"
# *   mínimas observaciones para el _split_ = 15
# *   El resto de los hiperparámetros que queden por defecto
#
# 5) ¿Cuál es el _accuracy_ que se obtiene?
# 6) Graficar la curva ROC. ¿Cuál es el valor de AUC?
# 7) Realizar nuevamente un árbol como en el punto 4, pero cambiar el hiperparámetro de máxima profundidad a 7.
# 8) ¿Cuál es la diferencia de AUC entre el modelo creado en el punto 4 y en el punto 7.
# 9) Crear un modelo de regresión logística con la misma partición creada en el punto 3. Usar los parámetros por defecto.
# 10) ¿Es correcto que use la métrica de _accuracy_ para saber si el modelo tiene buenos o malos resultados? ¿Por qué?
# 11) Graficar la curva ROC de la regresión. ¿Cuál es el AUC?. Es mejor el AUC de este modelo que el del modelo creado en el ejercicio 7?
# 12) Crear una regresión logística que mejore a la creada en el punto 9. ¿Qué hiperparámetros ajustastes?
# 13) Graficar las curvas ROC del mejor árbol de decisión creado en este ejercicio y la mejor regresión logística?. Realizar las curvas en el mismo gráfico.
# 14) Crear un XGBoost con los parámetros por defecto. ¿El AUC del XGBoost es mejor o peor al AUC del modelo creado en el punto 4?
# 15) ¿Qué variable es la que posee mayor explicación según _Feature Importance_?
# 16) Modificar los hiperparámetros del XGBoost hasta conseguir un modelo que de resultados mejores al creado en el punto 14.
# 17) Crear un modelo tipo LightGBM, utilizar los siguientes hiperparámetros:
# *   máxima profundidad = 3
# *   estimadores = 500
# *   learning rate = 0.01
# *   Resto de los parámetros por defecto.
#
# 18) ¿Qué AUC obtuvimos?
# 19) Graficar la curva ROC.
